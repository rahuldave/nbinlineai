# %% [markdown]
# # Learn through a notebook dialogue
#
# This lesson uses the notebook's **Learning** response style. Configure your own AI provider and model first. Run the Python setup, then work through the AI prompts **one at a time**. Do not use Run All for the unfinished dialogue: later prompt cells are intentionally blank so you can write your own attempts before asking the tutor. No generated answers are saved in this example.
#
# The first prompt has an explicit **Keep answer** pin. The second inherits the notebook's Keep setting. The final prompt has Keep off so it can be refreshed after a correction. The cell controls show and can reset these choices.

# %%
def count_even(
    numbers: list[int],  # Integers to inspect.
) -> int:  # Count returned by this deliberately flawed first draft.
    """Return the first draft's count so a learner can debug it."""
    return sum(value % 2 for value in numbers)


test_numbers: list[int] = [2, 4, 7]
print(f"First draft result: {count_even(test_numbers)}")
print("Expected even count: 2")

# %% [markdown]
# ## Turn 1: ask for a hint
#
# Run the next AI Prompt. Learning style asks the tutor to use questions and small hints rather than give the complete corrected function. **Pause when its answer appears.** Think about the question before writing your response below.

# %% [markdown]
# Help me understand why `count_even([2, 4, 7])` returns 1 although there are two even numbers. Ask one diagnostic question at a time. Do not write the complete corrected function.

# %% [markdown]
# ## Turn 2: your attempt
#
# Edit the blank AI Prompt below. Answer the tutor's question in your own words; for example, describe what `value % 2` produces for 2, 4, and 7. Then run only that prompt. Its preceding completed prompt and answer become conversation history. A blank prompt intentionally will not submit anything.

# %% [markdown]
# ## Turn 3: test a correction to the conversation
#
# After the tutor replies, double-click its **answer Markdown cell** and correct one statement or add your own note. Then fill the blank AI Prompt below with a follow-up such as “Given my corrected note above, what should I test next?” and run it. The current edited answer text, including unsaved changes, is used as history when the next prompt runs; save the notebook to preserve it for later sessions. The final prompt has **Keep answer off**, so rerunning it refreshes its paired answer. If you change an earlier prompt, rerun that prompt deliberately before relying on its old answer.

# %% [markdown]
# ## What Keep means here
#
# With notebook **Keep AI answers** on, a completed inherited answer survives Run All and Shift+Enter without another provider request. A blank, failed, cancelled, or deleted answer remains retryable. A cell with explicit Keep on stays protected even if you turn the notebook default off. Use **Use notebook setting** beside a cell checkbox to remove its explicit choice. Keep protects saved Markdown; it does not recreate Python kernel state after restart.

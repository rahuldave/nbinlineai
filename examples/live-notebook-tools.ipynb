# %% [markdown]
# # Live notebook cells and notes
#
# This lesson uses three browser-backed tools for the **current open notebook**, including unsaved edits. A fourth, `url_to_note`, is covered in the Python and web lesson. Import them in the Python kernel, then put the `&` references you want to offer in ordinary Markdown above the AI questions. Lower questions inherit those declarations. A direct Python call to these imported stubs raises a helpful error because JupyterLab handles their real operations.

# %%
from nbinlineai.tools import insert_markdown, list_cells, read_cell, tools_markdown

lesson_topic: str = "field observations"
print("Tools imported for this notebook.")

# %%
print(tools_markdown(["list_cells", "read_cell", "insert_markdown"]))

# %% [markdown]
# ## See the whole live notebook
#
# Run the next AI Prompt before executing the code cell below it. The list tool should still see that later, unexecuted source. It also sees unsaved source edits, unlike `find_notebook_cells` which reads a saved file.

# %% [markdown]
# ### Tools offered below
#
# - &`list_cells` — list cells in this open notebook.
# - &`read_cell` — read current unsaved source of one cell.
# - &`insert_markdown` — add an editable Markdown note.

# %% [markdown]
# Call &`list_cells` with `start=0` and `limit=20`. Tell me the ID of the code cell below this prompt and whether its source is visible even before I run it.

# %%
future_observation: str = "This source is below the first AI prompt and has not been run yet."

# %% [markdown]
# ## Read an unsaved edit
#
# Edit the source of the code cell with ID `future-unexecuted-cell` above, but **do not run or save** it yet. Add a short phrase of your own. Then run the next AI Prompt: the browser-backed reader should quote the changed live source. The Python kernel variable will still have its old value until you execute the edited code.

# %% [markdown]
# Call &`read_cell` with `cell_id="future-unexecuted-cell"`, `start_line=1`, and `end_line=10`. Quote the numbered live source you see, including my unsaved edit if I made one.

# %% [markdown]
# ## Insert a note into the notebook
#
# The next tool changes the open notebook by adding a Markdown cell. You can inspect or edit that note before saving the notebook. A tool result is not a file save: use JupyterLab Save to persist the new note.

# %% [markdown]
# Call &`insert_markdown` with `content="### Field note\nThis note was inserted into the live notebook; review it before saving."` and `after_cell_id="future-unexecuted-cell"`. Then tell me where the new note appeared.

# %% [markdown]
# ### Try a smaller selection
#
# Edit or remove one `&` line from the ordinary Markdown declaration above, then ask a new question below it. An import alone does not register a tool. Earlier AI questions can also declare tools for lower questions; code cells and AI answers cannot.

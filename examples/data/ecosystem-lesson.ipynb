# %% [markdown]
# # Tiny ecosystem lesson
#
# This saved notebook is a fixture for the bundled-tools walkthrough. It contains only harmless source text; no generated answer or credential is included.

# %%
organism_counts: dict[str, int] = {"oak": 12, "fern": 7, "lichen": 5}
organism_counts

# %% [markdown]
# ## Field note: lichen indicator
#
# The **lichen indicator** is a teaching clue about air quality. In this small invented survey, five lichen observations were recorded near the old wall. The number is sample data, not a scientific conclusion.

# %%
lichen_count: int = organism_counts["lichen"]
print(f"Recorded lichen observations: {lichen_count}")

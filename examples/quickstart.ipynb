# %% [markdown]
# # Try nbinlineai
#
# Run the next two code cells. Then choose **Configure AI** in the notebook toolbar, add a provider key, select the AI Prompt cell, and press **Shift+Enter**. The answer will appear directly below it.

# %%
score = 7
score

# %%
def add_bonus(value: int) -> int:
    """Return the score plus a bonus."""
    return score + value

# %% [markdown]
# What is $`score`? Call &`add_bonus` exactly once with value 3, then explain the result in one sentence.
